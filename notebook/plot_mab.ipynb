# %%
# %matplotlib notebook

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
log_file_true = [line.strip() for line in open("C:/Users/FEM/Gitprojects/MAB-strategy/results/UK_LAST_5_ALL_true_true.log", 'r')]
log_file_false = [line.strip() for line in open("C:/Users/FEM/Gitprojects/MAB-strategy/results/UK_LAST_5_ALL_false_false.log", 'r')]
# log_file_true = [line.strip() for line in open("C:/Users/FEM/Gitprojects/MAB-strategy/results/us_LAST_5_ALL_true_true.log", 'r')]
# log_file_false = [line.strip() for line in open("C:/Users/FEM/Gitprojects/MAB-strategy/results/us_LAST_5_ALL_false_false.log", 'r')]

# %%
sessions_true = [(float)(x[17:]) for x in log_file_true if x.startswith("Matching clicks")]
sessions_false = [(float)(x[17:]) for x in log_file_false if x.startswith("Matching clicks")]

# %%
sessions_true[:5]
# Out:
# [0.0774585592861813,
#  0.07854711016068239,
#  0.07954156803612195,
#  0.08113692639008795,
#  0.08187198309426257]

# %%
plt.figure(1)
ax = plt.subplot(1, 1, 1)
plt.plot(sessions_true, label="Use BEER")
plt.plot(sessions_false, label="Not use BEER")

# # Shrink current axis by 20%
# box = ax.get_position()
# ax.set_position([box.x0, box.y0, box.width * 0.5, box.height])

plt.legend(loc='upper left')
# ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
print("Use BEER: %f"%sessions_true[-1])
print("Not use BEER: %f"%sessions_false[-1])
# Out:
# Use BEER: 0.084178
# Not use BEER: 0.083920
