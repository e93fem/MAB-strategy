# %%
# %matplotlib notebook

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
log_file_first = [line.strip() for line in open("C:/Users/FEM/Gitprojects/MAB-strategy-2/results/Execute all_logs_UK.txt FIRST 3 ALL true true.txt", 'r')]
log_file_last = [line.strip() for line in open("C:/Users/FEM/Gitprojects/MAB-strategy-2/results/Execute all_logs_UK.txt LAST 3 ALL true true.txt", 'r')]
log_file_evenly = [line.strip() for line in open("C:/Users/FEM/Gitprojects/MAB-strategy-2/results/Execute all_logs_UK.txt EVENLY 3 ALL true true.txt", 'r')]
log_file_ageing_first = [line.strip() for line in open("C:/Users/FEM/Gitprojects/MAB-strategy-2/results/Execute all_logs_UK.txt AGEING_FIRST 3 ALL true true.txt", 'r')]
log_file_ageing_last = [line.strip() for line in open("C:/Users/FEM/Gitprojects/MAB-strategy-2/results/Execute all_logs_UK.txt AGEING_LAST 3 ALL true true.txt", 'r')]
# log_file_first = [line.strip() for line in open("C:/Users/FEM/Gitprojects/MAB-strategy-2/results/Execute all_logs_us.txt FIRST 3 ALL true true.txt", 'r')]
# log_file_last = [line.strip() for line in open("C:/Users/FEM/Gitprojects/MAB-strategy-2/results/Execute all_logs_us.txt LAST 3 ALL true true.txt", 'r')]
# log_file_evenly = [line.strip() for line in open("C:/Users/FEM/Gitprojects/MAB-strategy-2/results/Execute all_logs_us.txt EVENLY 3 ALL true true.txt", 'r')]
# log_file_ageing_first = [line.strip() for line in open("C:/Users/FEM/Gitprojects/MAB-strategy-2/results/Execute all_logs_us.txt AGEING_FIRST 3 ALL true true.txt", 'r')]
# log_file_ageing_last = [line.strip() for line in open("C:/Users/FEM/Gitprojects/MAB-strategy-2/results/Execute all_logs_us.txt AGEING_LAST 3 ALL true true.txt", 'r')]

# %%
sessions_first = [x for x in log_file_first if x.startswith("Total result:")]
sessions_last = [x for x in log_file_last if x.startswith("Total result:")]
sessions_evenly = [x for x in log_file_evenly if x.startswith("Total result:")]
sessions_ageing_first = [x for x in log_file_ageing_first if x.startswith("Total result:")]
sessions_ageing_last = [x for x in log_file_ageing_last if x.startswith("Total result:")]

# %%
sessions_first[0:4]
# Out:
# ['Total result: alpha: 30218.0, beta: 358563.3083496094, matches: 0.07772493005972045',
#  'Total result: alpha: 62046.0, beta: 730348.7409667969, matches: 0.07830188262519004',
#  'Total result: alpha: 94431.0, beta: 1075666.9116210938, matches: 0.0807035027258292',
#  'Total result: alpha: 128294.0, beta: 1431203.1801757812, matches: 0.0822662596834828']

# %%
sessions_val_first = pd.Series([float(x.split(" ")[7]) for x in sessions_first])
sessions_val_last = pd.Series([float(x.split(" ")[7]) for x in sessions_last])
sessions_val_evenly = pd.Series([float(x.split(" ")[7]) for x in sessions_evenly])
sessions_val_ageing_first = pd.Series([float(x.split(" ")[7]) for x in sessions_ageing_first])
sessions_val_ageing_last = pd.Series([float(x.split(" ")[7]) for x in sessions_ageing_last])

# %%
sessions_val_first[-4:]
# Out:
# 8     0.083815
# 9     0.085510
# 10    0.086997
# 11    0.087568
# dtype: float64

# %%
sessions_val_last[-4:]
# Out:
# 8     0.083833
# 9     0.085527
# 10    0.087018
# 11    0.087588
# dtype: float64

# %%
sessions_val_evenly[-4:]
# Out:
# 8     0.083813
# 9     0.085495
# 10    0.086975
# 11    0.087543
# dtype: float64

# %%
min_size = min(len(sessions_val_first), len(sessions_val_last), len(sessions_val_evenly), len(sessions_val_ageing_first), len(sessions_val_ageing_last))

# %%
plt.figure(1)
ax = plt.subplot(1, 1, 1)
plt.plot(sessions_val_first[:min_size-1], label='First')
plt.plot(sessions_val_last[:min_size-1], label='Last')
plt.plot(sessions_val_evenly[:min_size-1], label='Evenly')
plt.plot(sessions_val_ageing_first[:min_size-1], label='Ageing First')
plt.plot(sessions_val_ageing_last[:min_size-1], label='Ageing Last')
plt.legend(loc='upper left')
plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
print("First: %f"%sessions_val_first[min_size-1])
print("Last: %f"%sessions_val_last[min_size-1])
print("Evenly: %f"%sessions_val_evenly[min_size-1])
print("Ageing First: %f"%sessions_val_ageing_first[min_size-1])
print("Ageing Last: %f"%sessions_val_ageing_last[min_size-1])
# Out:
# First: 0.087568
# Last: 0.087588
# Evenly: 0.087543
# Ageing First: 0.087418
# Ageing Last: 0.087559

# %%
# Out:
# 33
